# %% [markdown]
# # RealCanadianSuperstoreAPI
#
# Selenium-based API for the Real Canadian Superstore
#
# ## To do
#
# * [ ] write README
# * [x] add setup.py
# * [x] add MANIFEST.in?
# * [x] add license file
# * [ ] conda recipe
# * [ ] cron job
# * [ ] docker container
# * [ ] throw/handle Timeout and NoSearchResults exceptions
# * [ ] docstrings
# * [ ] unit tests

# %%
# %load_ext autoreload
# %autoreload 2

import os

from grocery_helpers import RealCanadianSuperstoreAPI

# Create an instance of the API.
#
# Passing in the user_data_dir maintains authentication between sessions.

api = RealCanadianSuperstoreAPI(user_data_dir='C:/Users/%s/AppData/Local/Google/Chrome/User Data/Profile 1' % os.environ['USERNAME'],
                                data_directory=os.path.join('..', 'data'))

# %% [markdown]
# # Search for 'tomato' products

# %%
df = api.search('tomato')
df.head()
# Out:
#        productSKU                productName productBrand productCatalog  \
# 0  20426141001_KG      Tomato Beefsteak  Red         None        grocery
# 1  20112638001_EA            Kumato Tomatoes         None        grocery
# 2  20143381001_KG              Roma Tomatoes         None        grocery
# 3  20887498001_EA              Roma Tomatoes         None        grocery
# 4  20889119001_EA  Villagio Marzano Tomatoes         None        grocery
#
#   productVendor productPrice productQuantity dealBadge loyaltyBadge  \
# 0          None         1.76            None      None        false
# 1          None         3.98            None      None        false
# 2          None         0.79            None      None        false
# 3          None         6.98            None      None        false
# 4          None         6.98            None      None        false
#
#              textBadge productPosition productOrderId productVariant  \
# 0  PreviouslyPurchased            None           None           None
# 1                 None            None           None           None
# 2                 None            None           None           None
# 3                 None            None           None           None
# 4                 None            None           None           None
#
#    previouslyPurchased                                               link  \
# 0                 True  https://www.realcanadiansuperstore.ca/Food/Fru...
# 1                False  https://www.realcanadiansuperstore.ca/Food/Fru...
# 2                False  https://www.realcanadiansuperstore.ca/Food/Fru...
# 3                False  https://www.realcanadiansuperstore.ca/Food/Fru...
# 4                False  https://www.realcanadiansuperstore.ca/Food/Fru...
#
#                                           categories  \
# 0  [Fruits & Vegetables, Vegetables, Peppers & To...
# 1  [Fruits & Vegetables, Vegetables, Peppers & To...
# 2  [Fruits & Vegetables, Vegetables, Peppers & To...
# 3  [Fruits & Vegetables, Vegetables, Peppers & To...
# 4  [Fruits & Vegetables, Vegetables, Peppers & To...
#
#                                         unitPrice
# 0   [($1.76, ea), ($6.57, / 1kg), ($2.98, / 1lb)]
# 1                  [($3.98, ea), ($0.88, / 100g)]
# 2   [($0.79, ea), ($6.57, / 1kg), ($2.98, / 1lb)]
# 3                                   [($6.98, ea)]
# 4  [($6.98, ea), ($10.25, / 1kg), ($0.01, / 1lb)]

# %% [markdown]
# # Get info for a specific product

# %%
link = 'https://www.realcanadiansuperstore.ca/Food/Fruits-%26-Vegetables/Vegetables/Peppers-%26-Tomatoes/Kumato-Tomatoes/p/20112638001_EA'
product_info = api.get_product_info(link)
product_info
# Out:
# {'productSKU': '20112638001_EA',
#  'productName': 'Kumato Tomatoes',
#  'productBrand': None,
#  'productCatalog': 'grocery',
#  'productVendor': None,
#  'productPrice': '3.98',
#  'productQuantity': None,
#  'dealBadge': None,
#  'loyaltyBadge': 'false',
#  'textBadge': None,
#  'productPosition': None,
#  'productOrderId': None,
#  'productVariant': None,
#  'link': 'https://www.realcanadiansuperstore.ca/Food/Fruits-%26-Vegetables/Vegetables/Peppers-%26-Tomatoes/Kumato-Tomatoes/p/20112638001_EA',
#  'categories': ['Fruits & Vegetables',
#   'Vegetables',
#   'Peppers & Tomatoes',
#   'Kumato Tomatoes'],
#  'packageSize': '454 g',
#  'averageWeight': None,
#  'unitPrice': ['$0.88/ 100g']}

# %% [markdown]
# # Check if the user has signed in
#
# If not, display a button for the user to click once they have signed in.

# %%
import ipywidgets as widgets

api.init_driver()
button = widgets.Button(description='Click after signing in')

def on_button_clicked(b):
    if api.signed_in():
        print('User is signed in.')
        api.close_driver()
        button.layout.visibility = 'hidden'
button.on_click(on_button_clicked)

if api.signed_in():
    print('User is signed in.')
    button.layout.visibility = 'hidden'
    api.close_driver()
button
# Out:
# User is signed in.
# Button(description='Click after signing in', layout=Layout(visibility='hidden'), style=ButtonStyle())

# %% [markdown]
# # Add a product to the current order

# %%
link = 'https://www.realcanadiansuperstore.ca/Food/Fruits-%26-Vegetables/Vegetables/Peppers-%26-Tomatoes/Kumato-Tomatoes/p/20112638001_EA'
api.add_product_to_current_order(link, quantity=2)

# %% [markdown]
# # Get list of previous orders

# %%
df_orders = api.get_past_orders_list()
df_orders
# Out:
#            date    price                                               link  \
# 0  Mar 16, 2020  $109.78  https://www.realcanadiansuperstore.ca/account/...
# 1   Mar 7, 2020  $122.35  https://www.realcanadiansuperstore.ca/account/...
# 2  Feb 24, 2020   $58.21  https://www.realcanadiansuperstore.ca/account/...
#
#        orderNumber
# 0  531001886960368
# 1  531001871240125
# 2  531001871080015

# %% [markdown]
# # Get an itemized list of all receipts

# %%
df = api.get_itemized_order_history()
df.head()
# Out:
#                      description      productSKU  quantity        kg  price  \
# 0             Turkey Pepperettes     20976093_EA       1.0  0.375000   8.00
# 1  Marshmallows, Large Club Pack  20315322001_EA       1.0  1.000000   5.48
# 2      Potato Chips, Honey Dijon  20298997005_EA       1.0  0.220000   3.28
# 3                 Bananas, Bunch  20175355001_KG       NaN  1.206349   1.52
# 4             Crispy Rice Cereal     20781434_EA       1.0  0.640000   2.98
#
#        orderNumber          date
# 0  531001886960368  Mar 16, 2020
# 1  531001886960368  Mar 16, 2020
# 2  531001886960368  Mar 16, 2020
# 3  531001886960368  Mar 16, 2020
# 4  531001886960368  Mar 16, 2020

# %% [markdown]
# # Get a list of previously purchased products

# %%
df_products = api.get_product_list()
df_products.head()
# Out:
#                                  productName        productBrand  \
# 20976093_EA               Turkey Pepperettes           Schneider
# 20987179_EA           Original Veggie Straws   Sensible Portions
# 20809079_EA    Gluten Free All Purpose Flour  President's Choice
# 21173185_EA  Multigrain Rounds Tortilla Chip            Tostitos
# 20077630_EA                    Mango Chutney  President's Choice
#
#             productCatalog  productVendor  productPrice  productQuantity  \
# 20976093_EA        grocery            NaN          8.00              NaN
# 20987179_EA        grocery            NaN          7.98              NaN
# 20809079_EA        grocery            NaN          6.48              NaN
# 21173185_EA        grocery            NaN          4.78              NaN
# 20077630_EA        grocery            NaN          4.48              NaN
#
#             dealBadge  loyaltyBadge textBadge  productPosition  \
# 20976093_EA       NaN         False       NaN              NaN
# 20987179_EA       NaN         False       NaN              NaN
# 20809079_EA       NaN         False       NaN              NaN
# 21173185_EA     multi         False       New              NaN
# 20077630_EA       NaN         False       NaN              NaN
#
#              productOrderId  productVariant  \
# 20976093_EA             NaN             NaN
# 20987179_EA             NaN             NaN
# 20809079_EA             NaN             NaN
# 21173185_EA             NaN             NaN
# 20077630_EA             NaN             NaN
#
#                                                           link  \
# 20976093_EA  https://www.realcanadiansuperstore.ca/Food/Del...
# 20987179_EA  https://www.realcanadiansuperstore.ca/No-Navig...
# 20809079_EA  https://www.realcanadiansuperstore.ca/Food/Pan...
# 21173185_EA  https://www.realcanadiansuperstore.ca/Food/Pan...
# 20077630_EA  https://www.realcanadiansuperstore.ca/Food/Pan...
#
#                                                     categories packageSize  \
# 20976093_EA  ['Deli', 'Deli Meats', 'Specialty Cold Cuts', ...       375 g
# 20987179_EA  ['Pretzels & Crunch Snacks', 'Sensible Portion...       425 g
# 20809079_EA  ['Pantry', 'Baking Ingredients', 'Flour & Baki...       800 g
# 21173185_EA  ['Pantry', 'Chips & Salty Snacks', 'Potato Chi...       450 g
# 20077630_EA  ['Pantry', 'Packaged Meals & Kits', 'Indian Ki...      250 mL
#
#             averageWeight         unitPrice     kg
# 20976093_EA           NaN   ['$2.13/ 100g']  0.375
# 20987179_EA           NaN   ['$1.88/ 100g']  0.425
# 20809079_EA           NaN   ['$0.81/ 100g']  0.800
# 21173185_EA           NaN   ['$1.06/ 100g']  0.450
# 20077630_EA           NaN  ['$1.79/ 100mL']  0.250
